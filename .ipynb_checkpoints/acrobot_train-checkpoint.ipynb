# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
env = gym.make("Acrobot-v1", render_mode=None)

# Turn continuous state space into discrete state space
n_bin_edges = 15
costh1 = np.linspace(env.observation_space.low[0], env.observation_space.high[0], n_bin_edges)
sinth1 = np.linspace(env.observation_space.low[1], env.observation_space.high[1], n_bin_edges)
costh2 = np.linspace(env.observation_space.low[2], env.observation_space.high[2], n_bin_edges)
sinth2 = np.linspace(env.observation_space.low[3], env.observation_space.high[3], n_bin_edges)
omega1 = np.linspace(env.observation_space.low[4], env.observation_space.high[4], n_bin_edges)
omega2 = np.linspace(env.observation_space.low[5], env.observation_space.high[5], n_bin_edges)
state_space = np.vstack((costh1, sinth1, costh2, sinth2, omega1, omega2))

q = np.zeros((len(costh1)-1, len(sinth1)-1, 
              len(costh2)-1, len(sinth2)-1, 
              len(omega1)-1, len(omega2)-1,
              env.action_space.n))

# %%
# Q-learning hyperparameters
alpha = 0.1                     # Learning rate
gamma = 0.95                    # Discount factor
epsilon = 1                     # Probability of random action
epsilon_min = 0.05              # Minimum probability of random action
epsilon_decay = 0.00005         # Epsilon decay after each episode

best_reward = float('-inf')     # Best reward from any episode
mean_reward = float('-inf')     # Mean reward over the last n (specified later) episodes
rewards_per_episode = []        # Rewards of each episode

epoch = 0                       # Index of current epoch of training

while (True):
    observation = env.reset(seed=0)[0]
    state = np.zeros(state_space.shape[0], dtype=int)
    
    # Encode discrete state from continuous observation. The -1's and min() prevent IndexErrors through finagling
    for i in range(len(observation)):
        state[i] = min(np.digitize(observation[i], state_space[i])-1, q.shape[0]-1)

    new_observation = np.zeros(len(observation))
    new_state = np.zeros(state_space.shape[0], dtype=int)

    rewards = 0               # Total reward over one episode
    terminated = False        # Whether the goal has been reached this episode
    
    while not terminated:    
        if np.random.rand() < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(q[*state, :])

        new_observation, reward, terminated, _, _ = env.step(action)
        for i in range(len(observation)):
            new_state[i] = min(np.digitize(new_observation[i], state_space[i])-1, q.shape[0]-1)
            
        q[*state, action] += alpha * (reward + gamma * np.max(q[*new_state, :]) - q[*state, action])

        observation[:] = new_observation
        state[:] = new_state
        
        rewards += reward

    rewards_per_episode.append(rewards)
    
    if (rewards > best_reward):
        best_reward = rewards
        f = open('acrobot.pkl', 'wb')
        pickle.dump(q, f)
        f.close()
        
    if epoch != 0 and epoch % 100 == 0:
        mean_reward = np.mean(rewards_per_episode[len(rewards_per_episode)-100:])
        print(f"Episode: {epoch}, Epsilon: {epsilon:0.2f}, Best Reward: {best_reward:0.1f}, Mean Rewards {mean_reward:0.1f}")

        # Graph mean rewards
        mean_rewards = []
        for t in range(epoch):
            # Calculate mean reward over the t-100 episodes
            mean_rewards.append(np.mean(rewards_per_episode[max(0, t-100):(t+1)]))
        plt.plot(mean_rewards)
        plt.xlabel("Episode")
        plt.ylabel("Mean Recent Reward")
        plt.title("Q-table Acrobot Agent Training Progress")
        plt.savefig(f'acrobot.png')

    if mean_reward > env.spec.reward_threshold - 5:
        break
    
    epsilon = max(epsilon - epsilon_decay, epsilon_min)
    epoch += 1
    
env.close()
# Out:
# Episode: 100, Epsilon: 1.00, Best Reward: -305.0, Mean Rewards -2181.7
, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -243.0
# Episode: 51300, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -271.7
# Episode: 51400, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -274.0
# Episode: 51500, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -274.2
# Episode: 51600, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -297.3
# Episode: 51700, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -306.1
# Episode: 51800, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -268.8
# Episode: 51900, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -255.6
# Episode: 52000, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -246.8
# Episode: 52100, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -252.3
# Episode: 52200, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -242.3
# Episode: 52300, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -229.3
# Episode: 52400, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -210.2
# Episode: 52500, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -221.1
# Episode: 52600, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -231.4
# Episode: 52700, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -206.4
# Episode: 52800, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -237.6
# Episode: 52900, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -245.5
# Episode: 53000, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -226.9
# Episode: 53100, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -224.5
# Episode: 53200, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -218.7
# Episode: 53300, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -229.5
# Episode: 53400, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -203.9
# Episode: 53500, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -196.9
# Episode: 53600, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -225.3
# Episode: 53700, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -214.9
# Episode: 53800, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -222.7
# Episode: 53900, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -227.2
# Episode: 54000, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -218.9
# Episode: 54100, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -202.6
# Episode: 54200, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -191.4
# Episode: 54300, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -208.4
# Episode: 54400, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -221.0
# Episode: 54500, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -251.3
# Episode: 54600, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -224.2
# Episode: 54700, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -216.8
# Episode: 54800, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -224.7
# Episode: 54900, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -231.7
# Episode: 55000, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -204.9
# Episode: 55100, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -225.0
# Episode: 55200, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -278.9
# Episode: 55300, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -232.9
# Episode: 55400, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -230.2
# Episode: 55500, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -219.8
# Episode: 55600, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -205.4
# Episode: 55700, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -244.2
# Episode: 55800, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -208.7
# Episode: 55900, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -255.0
# Episode: 56000, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -196.7
# Episode: 56100, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -193.8
# Episode: 56200, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -190.4
# Episode: 56300, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -201.9
# Episode: 56400, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -202.2
# Episode: 56500, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -200.4
# Episode: 56600, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -213.0
# Episode: 56700, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -207.6
# Episode: 56800, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -207.4
# Episode: 56900, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -222.5
# Episode: 57000, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -233.5
# Episode: 57100, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -213.6
# Episode: 57200, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -211.0
# Episode: 57300, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -226.4
# Episode: 57400, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -216.7
# Episode: 57500, Epsilon: 0.05, Best Reward: -82.0, Mean Rewards -205.4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 66
#      64     plt.ylabel("Mean Recent Reward")
#      65     plt.title("Q-table Acrobot Agent Training Progress")
# ---> 66     plt.savefig(f'acrobot.png')
#      68 if mean_reward > env.spec.reward_threshold - 5:
#      69     break
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1252, in savefig(*args, **kwargs)
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
#    1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
# -> 1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:3226, in _AxesBase.draw(self, renderer)
#    3223 if artists_rasterized:
#    3224     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3226 mimage._draw_list_compositing_images(
#    3227     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3229 renderer.close_group('axes')
#    3230 self.stale = False
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\lines.py:774, in Line2D.draw(self, renderer)
#     772     subslice = slice(max(i0 - 1, 0), i1 + 1)
#     773     self.ind_offset = subslice.start
# --> 774     self._transform_path(subslice)
#     775 else:
#     776     subslice = None
#
# File ~\anaconda3\Lib\site-packages\matplotlib\lines.py:740, in Line2D._transform_path(self, subslice)
#     738 if subslice is not None:
#     739     xy = STEP_LOOKUP_MAP[self._drawstyle](*self._xy[subslice, :].T)
# --> 740     _path = Path(np.asarray(xy).T,
#     741                  _interpolation_steps=self._path._interpolation_steps)
#     742 else:
#     743     _path = self._path
#
# KeyboardInterrupt:
