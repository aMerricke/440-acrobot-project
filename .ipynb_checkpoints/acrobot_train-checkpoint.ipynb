# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
env = gym.make("Acrobot-v1", render_mode=None)

# Turn continuous state space into discrete state space
n_bin_edges = 15
costh1 = np.linspace(env.observation_space.low[0], env.observation_space.high[0], n_bin_edges)
sinth1 = np.linspace(env.observation_space.low[1], env.observation_space.high[1], n_bin_edges)
costh2 = np.linspace(env.observation_space.low[2], env.observation_space.high[2], n_bin_edges)
sinth2 = np.linspace(env.observation_space.low[3], env.observation_space.high[3], n_bin_edges)
omega1 = np.linspace(env.observation_space.low[4], env.observation_space.high[4], n_bin_edges)
omega2 = np.linspace(env.observation_space.low[5], env.observation_space.high[5], n_bin_edges)
state_space = np.vstack((costh1, sinth1, costh2, sinth2, omega1, omega2))

q = np.zeros((len(costh1)-1, len(sinth1)-1, 
              len(costh2)-1, len(sinth2)-1, 
              len(omega1)-1, len(omega2)-1,
              env.action_space.n))

# %%
# Q-learning hyperparameters
alpha = 0.1                     # Learning rate
gamma = 0.95                    # Discount factor
epsilon = 1                     # Probability of random action
epsilon_min = 0.05              # Minimum probability of random action
epsilon_decay = 0.00001         # Epsilon decay after each episode

best_reward = float('-inf')     # Best reward from any episode
mean_reward = float('-inf')     # Mean reward over the last n (specified later) episodes
rewards_per_episode = []        # Rewards of each episode

epoch = 0                       # Index of current epoch of training

while (True):
    observation = env.reset(seed=0)[0]
    state = np.zeros(state_space.shape[0], dtype=int)
    
    # Encode discrete state from continuous observation. The -1's and min() prevent IndexErrors through finagling
    for i in range(len(observation)):
        state[i] = min(np.digitize(observation[i], state_space[i])-1, q.shape[0]-1)

    new_observation = np.zeros(len(observation))
    new_state = np.zeros(state_space.shape[0], dtype=int)

    rewards = 0               # Total reward over one episode
    terminated = False        # Whether the goal has been reached this episode
    
    while not terminated:    
        if np.random.rand() < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(q[*state, :])

        new_observation, reward, terminated, _, _ = env.step(action)
        for i in range(len(observation)):
            new_state[i] = min(np.digitize(new_observation[i], state_space[i])-1, q.shape[0]-1)
            
        q[*state, action] += alpha * (reward + gamma * np.max(q[*new_state, :]) - q[*state, action])

        observation[:] = new_observation
        state[:] = new_state
        
        rewards += reward

    rewards_per_episode.append(rewards)
    
    if (rewards > best_reward):
        best_reward = rewards
        f = open('acrobot.pkl', 'wb')
        pickle.dump(q, f)
        f.close()
        
    if epoch != 0 and epoch % 100 == 0:
        mean_reward = np.mean(rewards_per_episode[len(rewards_per_episode)-100:])
        print(f"Episode: {epoch}, Epsilon: {epsilon:0.2f}, Best Reward: {best_reward:0.1f}, Mean Rewards {mean_reward:0.1f}")

        # Graph mean rewards
        mean_rewards = []
        for t in range(epoch):
            # Calculate mean reward over the t-100 episodes
            mean_rewards.append(np.mean(rewards_per_episode[max(0, t-100):(t+1)]))
        plt.plot(mean_rewards)
        plt.xlabel("Episode")
        plt.ylabel("Mean Recent Reward")
        plt.title("Acrobot Agent Training Progress")
        plt.savefig(f'acrobot.png')

    if mean_reward > env.spec.reward_threshold - 5:
        break
    
    epsilon = max(epsilon - epsilon_decay, epsilon_min)
    epoch += 1
    
env.close()
# Out:
# Episode: 100, Epsilon: 1.00, Best Reward: -375.0, Mean Rewards -2195.3
# Episode: 200, Epsilon: 1.00, Best Reward: -375.0, Mean Rewards -1895.1
# Episode: 300, Epsilon: 1.00, Best Reward: -375.0, Mean Rewards -1983.7
# Episode: 400, Epsilon: 1.00, Best Reward: -375.0, Mean Rewards -1923.9
# Episode: 500, Epsilon: 1.00, Best Reward: -335.0, Mean Rewards -2048.8
# Episode: 600, Epsilon: 0.99, Best Reward: -335.0, Mean Rewards
, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -366.9
# Episode: 139200, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -372.2
# Episode: 139300, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -362.7
# Episode: 139400, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -382.8
# Episode: 139500, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -357.1
# Episode: 139600, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -380.6
# Episode: 139700, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -419.2
# Episode: 139800, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -425.8
# Episode: 139900, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -373.0
# Episode: 140000, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -369.0
# Episode: 140100, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -369.0
# Episode: 140200, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -366.8
# Episode: 140300, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -356.7
# Episode: 140400, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -410.8
# Episode: 140500, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -395.9
# Episode: 140600, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -407.0
# Episode: 140700, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -399.9
# Episode: 140800, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -356.7
# Episode: 140900, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -353.6
# Episode: 141000, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -390.9
# Episode: 141100, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -390.1
# Episode: 141200, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -400.1
# Episode: 141300, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -412.6
# Episode: 141400, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -369.2
# Episode: 141500, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -345.4
# Episode: 141600, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -330.5
# Episode: 141700, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -357.7
# Episode: 141800, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -381.7
# Episode: 141900, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -334.4
# Episode: 142000, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -399.1
# Episode: 142100, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -377.2
# Episode: 142200, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -374.9
# Episode: 142300, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -405.9
# Episode: 142400, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -425.1
# Episode: 142500, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -350.8
# Episode: 142600, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -365.9
# Episode: 142700, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -366.1
# Episode: 142800, Epsilon: 0.05, Best Reward: -92.0, Mean Rewards -391.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 66
#      64     plt.ylabel("Mean Recent Reward")
#      65     plt.title("Acrobot Agent Training Progress")
# ---> 66     plt.savefig(f'acrobot.png')
#      68 if mean_reward > env.spec.reward_threshold - 5:
#      69     break
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:429, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     424 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     425     """
#     426     Draw the canvas, then save it using `.image.imsave` (to which
#     427     *pil_kwargs* and *metadata* are forwarded).
#     428     """
# --> 429     FigureCanvasAgg.draw(self)
#     430     mpl.image.imsave(
#     431         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:3226, in _AxesBase.draw(self, renderer)
#    3223 if artists_rasterized:
#    3224     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3226 mimage._draw_list_compositing_images(
#    3227     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3229 renderer.close_group('axes')
#    3230 self.stale = False
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\lines.py:822, in Line2D.draw(self, renderer)
#     820         gc.set_dashes(*self._dash_pattern)
#     821         renderer.draw_path(gc, tpath, affine.frozen())
# --> 822         gc.restore()
#     824 if self._marker and self._markersize > 0:
#     825     gc = renderer.new_gc()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:721, in GraphicsContextBase.restore(self)
#     718     self._snap = gc._snap
#     719     self._sketch = gc._sketch
# --> 721 def restore(self):
#     722     """
#     723     Restore the graphics context from the stack - needed only
#     724     for backends that save graphics contexts on a stack.
#     725     """
#     727 def get_alpha(self):
#
# KeyboardInterrupt:
