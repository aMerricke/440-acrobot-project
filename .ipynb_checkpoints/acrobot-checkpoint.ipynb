# %%
pip install gymnasium[classic_control]
# Out:
# Requirement already satisfied: gymnasium[classic_control] in c:\users\merrick\anaconda3\lib\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\merrick\anaconda3\lib\site-packages (from gymnasium[classic_control]) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\merrick\anaconda3\lib\site-packages (from gymnasium[classic_control]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\merrick\anaconda3\lib\site-packages (from gymnasium[classic_control]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\merrick\anaconda3\lib\site-packages (from gymnasium[classic_control]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\merrick\anaconda3\lib\site-packages (from gymnasium[classic_control]) (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym
env = gym.make('Acrobot-v1', render_mode="human")
observation, info = env.reset(seed=123, options={"low": -0.2, "high": 0.2})  # default low=-0.1, high=0.1

episode_over = False
total_reward = 0

while not episode_over:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    
    total_reward += reward
    episode_over = terminated or truncated

print(f"Episode finished. Total reward: {total_reward}")
env.close()
# Out:
# C:\Users\Merrick\anaconda3\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Episode finished. Total reward: -500.0
